# %% [markdown]
# # Prepare Sentiment Analysis with VADER

# %% [markdown]
# ## Import Packages and Load Data

# %%
# Necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(font_scale=1.5, style = 'whitegrid', color_codes=True)

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Skripsi/Twitter_topics.csv')

# %%
df.head()
# Out:
#                                                                                                                                                                                                       Text  \
# 0                                                               mathlievetradingsignaltime075924design closing point accord thecryptocurrency ai btc etherum bnb orc20 bch xrp usdt shib link dydx chatgpt
# 1                                                                            chatgpt cause website scrap stop get updated plan train model still also think far early ai company get sue oblivion ip theft
# 2                                                                       one way education foundation could stop pay many people endless englishmajoring chatgpt start pay people system work systemsmatter
# 3  african union commission fall victim cybercrime use deep fake impersonate head moussa faki incident highlight need strong cybersecurity measure worldwide cybersecurity deepfakes africanunioncommis...
# 4                                                                                                                                                                                                  chatgpt
#
#                                                                                                                                                                                                      Token  \
# 0                                                                  ['design', 'closing', 'point', 'accord', 'ai', 'btc', 'etherum', 'bnb', 'orc', 'bch', 'xrp', 'usdt', 'shib', 'link', 'dydx', 'chatgpt']
# 1         ['chatgpt', 'cause', 'website', 'scrap', 'stop', 'get', 'updated', 'plan', 'train', 'model', 'still', 'also', 'think', 'far', 'early', 'ai', 'company', 'get', 'sue', 'oblivion', 'ip', 'theft']
# 2                ['one', 'way', 'education', 'foundation', 'could', 'stop', 'pay', 'many', 'people', 'endless', 'englishmajoring', 'chatgpt', 'start', 'pay', 'people', 'system', 'work', 'systemsmatter']
# 3  ['african', 'union', 'commission', 'fall', 'victim', 'cybercrime', 'use', 'deep', 'fake', 'impersonate', 'head', 'moussa', 'faki', 'incident', 'highlight', 'need', 'strong', 'cybersecurity', 'meas...
# 4                                                                                                                                                                                              ['chatgpt']
#
#    Dominant_Topic  Contribution%                       Topic_Name
# 0               3          60.46                 T3 Experiment AI
# 1               1          91.16        T1 Information Technology
# 2               4          91.76  T4 Random Ask and Conversations
# 3               1          74.41        T1 Information Technology
# 4               1          25.00        T1 Information Technology

# %%
# convert the string of words in the 'Tweet_lemmatized' column to a list for each row in the dataframe
df['Token'] = df['Token'].apply(lambda x: ast.literal_eval(x))

# %%
df['Text'] = df['Token'].apply(lambda x: ' '.join(word for word in x))

# %%
df.head()
# Out:
#                                                                                                                                                                                 Text  \
# 0                                                                                             design closing point accord ai btc etherum bnb orc bch xrp usdt shib link dydx chatgpt
# 1                                                      chatgpt cause website scrap stop get updated plan train model still also think far early ai company get sue oblivion ip theft
# 2                                                 one way education foundation could stop pay many people endless englishmajoring chatgpt start pay people system work systemsmatter
# 3  african union commission fall victim cybercrime use deep fake impersonate head moussa faki incident highlight need strong cybersecurity measure worldwide cybersecurity deepfakes
# 4                                                                                                                                                                            chatgpt
#
#                                                                                                                                                                                                      Token  \
# 0                                                                                                  [design, closing, point, accord, ai, btc, etherum, bnb, orc, bch, xrp, usdt, shib, link, dydx, chatgpt]
# 1                                                     [chatgpt, cause, website, scrap, stop, get, updated, plan, train, model, still, also, think, far, early, ai, company, get, sue, oblivion, ip, theft]
# 2                                                    [one, way, education, foundation, could, stop, pay, many, people, endless, englishmajoring, chatgpt, start, pay, people, system, work, systemsmatter]
# 3  [african, union, commission, fall, victim, cybercrime, use, deep, fake, impersonate, head, moussa, faki, incident, highlight, need, strong, cybersecurity, measure, worldwide, cybersecurity, deepfa...
# 4                                                                                                                                                                                                [chatgpt]
#
#    Dominant_Topic  Contribution%                       Topic_Name
# 0               3          60.46                 T3 Experiment AI
# 1               1          91.16        T1 Information Technology
# 2               4          91.76  T4 Random Ask and Conversations
# 3               1          74.41        T1 Information Technology
# 4               1          25.00        T1 Information Technology

# %%
#only save the columns that we need for sentiment analysis
df_s = df[['Text', 'Dominant_Topic', 'Topic_Name']].copy()
# drop date column
df_s.head()
# Out:
#                                                                                                                                                                                 Text  \
# 0                                                                                             design closing point accord ai btc etherum bnb orc bch xrp usdt shib link dydx chatgpt
# 1                                                      chatgpt cause website scrap stop get updated plan train model still also think far early ai company get sue oblivion ip theft
# 2                                                 one way education foundation could stop pay many people endless englishmajoring chatgpt start pay people system work systemsmatter
# 3  african union commission fall victim cybercrime use deep fake impersonate head moussa faki incident highlight need strong cybersecurity measure worldwide cybersecurity deepfakes
# 4                                                                                                                                                                            chatgpt
#
#    Dominant_Topic                       Topic_Name
# 0               3                 T3 Experiment AI
# 1               1        T1 Information Technology
# 2               4  T4 Random Ask and Conversations
# 3               1        T1 Information Technology
# 4               1        T1 Information Technology

# %% [markdown]
# ## VADER Model Implementation

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# %%time
#Initialize the vader sentiment analyser
vader_model = SentimentIntensityAnalyzer()
#apply VADER model to the dataset
df_s['VADER_Scores'] = df_s['Text'].apply(lambda x: vader_model.polarity_scores(x))
# Out:
# CPU times: user 332 ms, sys: 799 µs, total: 333 ms
# Wall time: 361 ms

# %%
#VADER returned the scores as a dictionary
#get the compound score as the polarity score
df_s['VADER_Polarity'] = df_s['VADER_Scores'].apply(lambda x: x['compound'])

#Assign labels for each tweet, depending on the polarity.
#Sentiment labels are assigned according to the polarity score:
'''
-1 to -0.25 => negative;
-0.25 and 0.25 => neutral;
0.25 to 1 => positive;
'''
df_s['VADER_Sentiment'] = pd.cut(df_s['VADER_Polarity'],
                                bins = [-1, -0.25, 0.25, 1],
                                labels=['Negative', 'Neutral', 'Positive'])

# %%
df_s.drop(['VADER_Scores'], axis=1, inplace = True)

# %%
df_s.head()
# Out:
#                                                                                                                                                                                 Text  \
# 0                                                                                             design closing point accord ai btc etherum bnb orc bch xrp usdt shib link dydx chatgpt
# 1                                                      chatgpt cause website scrap stop get updated plan train model still also think far early ai company get sue oblivion ip theft
# 2                                                 one way education foundation could stop pay many people endless englishmajoring chatgpt start pay people system work systemsmatter
# 3  african union commission fall victim cybercrime use deep fake impersonate head moussa faki incident highlight need strong cybersecurity measure worldwide cybersecurity deepfakes
# 4                                                                                                                                                                            chatgpt
#
#    Dominant_Topic                       Topic_Name  VADER_Polarity  \
# 0               3                 T3 Experiment AI          0.0000
# 1               1        T1 Information Technology         -0.2960
# 2               4  T4 Random Ask and Conversations         -0.4588
# 3               1        T1 Information Technology          0.1280
# 4               1        T1 Information Technology          0.0000
#
#   VADER_Sentiment
# 0         Neutral
# 1        Negative
# 2        Negative
# 3         Neutral
# 4         Neutral

# %%
# Simpan DataFrame ke dalam file CSV
df_s.to_csv('Twitter_VADER.csv', index=False)
